# %%
import os
import cv2
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import torch
import torchvision.transforms as transforms
import pandas as pd
from torch.nn.utils.rnn import pad_sequence

# %%
root_path = r"D:\dataset\eye\Train"

# %%
csv_path = root_path + "/Train.csv"

# %%
root_path = r"F:\Train\Train"

# %%
csv_path = root_path + "/Transformed_Train.csv"

# %%
csv_path
# Out:
# 'D:\\dataset\\eye\\Train/Train.csv'

# %%
data_source = pd.read_csv(csv_path)

# %%
for index, row in data_source.iterrows():
    print(index, row[-1], row[-2])
    break
# Out:
# 0 0_L 0
# C:\Users\DentaLink\AppData\Local\Temp\ipykernel_19520\938019873.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(index, row[-1], row[-2])

# %%
os.listdir(root_path+"/Train/" + row[-1])
# Out:
# C:\Users\DentaLink\AppData\Local\Temp\ipykernel_19520\1300416951.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   os.listdir(root_path+"/Train/" + row[-1])
# ['0.jpg', '1.jpg', '2.jpg', '3.jpg', '4.jpg', '5.jpg', '6.jpg', '7.jpg']

# %%
root_path+"/Train/" + row[-1]
# Out:
# C:\Users\DentaLink\AppData\Local\Temp\ipykernel_19520\3111792703.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   root_path+"/Train/" + row[-1]
# 'D:\\dataset\\eye\\Train/Train/0_L'

# %%
def anylaized(data_source):
    data_key = [ "Impression", "HyperF_Type", "HyperF_Area(DA)", "HyperF_Fovea", "HyperF_ExtraFovea", "HyperF_Y", 
      "HypoF_Type" ,"HypoF_Area(DA)","HypoF_Fovea", "HypoF_ExtraFovea"
    ,"HypoF_Y","CNV","Vascular abnormality (DR)","Pattern"]
    discribe_word = {}
    discribe_key_word = {}
    for keyword in data_key:
        impress_type = {}
        for i in data_source[keyword]:
            #if i is None:
            if i is np.nan:
                i = 'nan'
            word_list = i.split(',')

            for word in word_list:
                if word == '':
                    continue
                if word not in impress_type:
                    impress_type[word] = 1
                else:
                    impress_type[word] += 1
        discribe_key_word[keyword] = impress_type
        for key, value in impress_type.items():
            if key not in discribe_word:
                discribe_word[key] = 1
            else:
                discribe_word[key] += 1
    return discribe_word, discribe_key_word

# %%
from torch.utils.data import Dataset

class DataLoad(Dataset):
    def __init__(self, root_path = r"D:\dataset\eye\Train" ) -> None:
        self.root_path = root_path
        csv_path = root_path + "/Train.csv"
        self.data_source = pd.read_csv(csv_path)
        self.load_data(self.data_source)
        self.discribe_word, self.discribe_key_word = anylaized(self.data_source)
        
    def load_data(self, data_source):
        photo_set = []
        img_root_path = self.root_path + "/Train/"
        for index, row in data_source.iterrows():
            file_id = row[-2]
            file_folder = row[-1]
            file_path = img_root_path + file_folder + "/"
            if os.path.exists(file_path):
                file_name_list = os.listdir(file_path)
                for file_name in file_name_list:
                    img_obj = {
                        "image" : file_path  + file_name,
                        "gt" : None,
                    }
                    photo_set.append(img_obj)
            else:
                print(file_path, "not exists!"  )
                
        self.photo_set = photo_set
        self.total_number = len(self.photo_set)
        print("total load data:", self.total_number)
    
    def set_gan(self):
        pass
    
    def __len__(self):
        return len(self.photo_set)

    def __getitem__(self, index):
                """
        获取对应index的图像,并视情况进行数据增强
        """
        if index >= self.total_number:
            raise StopIteration
        try:
            re_index = index
            image_src_path, image_gt_path = self.photo_set[re_index]['image'], self.photo_set[re_index]['gt']
            
            if self.datagen is not None:
                image_src = self.datagan_read(image_src)
                seed = torch.random.seed()
                torch.random.manual_seed(seed)
                image_src = self.datagan_random(image_src)
                image_src = self.datagan_normal(image_src)


            image_edge_mask = self.get_edge(image_mask)
            if self.datagen_gt is not None:

                image_mask = self.datagan_read(image_mask)
                torch.random.manual_seed(seed)
                image_mask = self.datagan_random(image_mask)
                image_mask = self.datagan_normal(image_mask)



            return image_src, image_mask #
        except Exception as e:
            print("发现异常")
            print(e.__class__.__name__)
            print(e)
            print(index)
            print(traceback.print_exc())

# %%
a = DataLoad()
# Out:
# C:\Users\DentaLink\AppData\Local\Temp\ipykernel_1468\473455136.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   file_id = row[-2]
# C:\Users\DentaLink\AppData\Local\Temp\ipykernel_1468\473455136.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   file_folder = row[-1]
# D:\dataset\eye\Train/Train/454_L/ not exists!
# D:\dataset\eye\Train/Train/454_R/ not exists!
# D:\dataset\eye\Train/Train/611_L/ not exists!
# D:\dataset\eye\Train/Train/611_R/ not exists!
# D:\dataset\eye\Train/Train/729_L/ not exists!
# D:\dataset\eye\Train/Train/1412_L/ not exists!
# D:\dataset\eye\Train/Train/1412_R/ not exists!
# D:\dataset\eye\Train/Train/1417_L/ not exists!
# D:\dataset\eye\Train/Train/1417_R/ not exists!
# D:\dataset\eye\Train/Train/1425_L/ not exists!
# D:\dataset\eye\Train/Train/1425_R/ not exists!
# D:\dataset\eye\Train/Train/1426_L/ not exists!
# D:\dataset\eye\Train/Train/1426_R/ not exists!
# D:\dataset\eye\Train/Train/1427_L/ not exists!
# D:\dataset\eye\Train/Train/1427_R/ not exists!
# D:\dataset\eye\Train/Train/1429_L/ not exists!
# D:\dataset\eye\Train/Train/1429_R/ not exists!
# D:\dataset\eye\Train/Train/1430_L/ not exists!
# D:\dataset\eye\Train/Train/1430_R/ not exists!
# D:\dataset\eye\Train/Train/1431_L/ not exists!
# D:\dataset\eye\Train/Train/1431_R/ not exists!
# D:\dataset\eye\Train/Train/1432_R/ not exists!
# D:\dataset\eye\Train/Train/1434_L/ not exists!
# D:\dataset\eye\Train/Train/1434_R/ not exists!
# D:\dataset\eye\Train/Train/1435_L/ not exists!
# D:\dataset\eye\Train/Train/1435_R/ not exists!
# D:\dataset\eye\Train/Train/1436_L/ not exists!
# D:\dataset\eye\Train/Train/1436_R/ not exists!
# D:\dataset\eye\Train/Train/1439_L/ not exists!
# D:\dataset\eye\Train/Train/1439_R/ not exists!
# D:\dataset\eye\Train/Train/1441_L/ not exists!
# D:\dataset\eye\Train/Train/1441_R/ not exists!
# D:\dataset\eye\Train/Train/1442_L/ not exists!
# D:\dataset\eye\Train/Train/1442_R/ not exists!
# D:\dataset\eye\Train/Train/1443_L/ not exists!
# D:\dataset\eye\Train/Train/1443_R/ not exists!
# D:\dataset\eye\Train/Train/1444_R/ not exists!
# D:\dataset\eye\Train/Train/1445_L/ not exists!
# D:\dataset\eye\Train/Train/1447_L/ not exists!
# D:\dataset\eye\Train/Train/1447_R/ not exists!
# D:\dataset\eye\Train/Train/1452_L/ not exists!
# D:\dataset\eye\Train/Train/1452_R/ not exists!
# D:\dataset\eye\Train/Train/1563_L/ not exists!
# 33559

# %%
a.photo_set
# Out:
# [{'image': 'D:\\dataset\\eye\\Train/Train/0_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/0_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/1_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/2_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/7_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/8_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/9_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/10_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/13_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/14_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/15_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/16_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/19_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/20_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/22_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/27.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/28.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/29.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/30.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/31.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/32.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/23_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/25_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/26_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/27_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/28_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/29_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/30_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/27.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/28.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/29.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/30.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/31.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/32.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/33.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/34.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/35.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/36.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/37.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/38.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/39.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/40.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/41.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/42.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/43.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/44.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/45.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/46.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/47.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/48.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/49.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/50.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/51.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/52.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/31_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/34_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/27.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/28.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/29.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/30.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/31.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/32.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/33.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/34.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/35.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/36.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/37.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/38.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/39.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/40.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/41.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/42.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/43.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/44.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/45.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/46.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/47.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/48.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/49.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/50.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/35_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/38_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/27.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/28.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/39_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/44_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/24.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/25.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/26.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/27.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/45_R/12.jpg', 'gt': None},
# ...
#  {'image': 'D:\\dataset\\eye\\Train/Train/50_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/55_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/55_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/55_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/55_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/55_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/56_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/58_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/59_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/21.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/22.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/23.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/60_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/64_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/65_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/66_R/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/67_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/70_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/70_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/70_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/20.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/71_R/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/14.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/15.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/16.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/17.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/18.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/19.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/2.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/3.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/4.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/5.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/6.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/7.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/8.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_L/9.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/0.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/1.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/10.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/11.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/12.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/13.jpg', 'gt': None},
#  {'image': 'D:\\dataset\\eye\\Train/Train/73_R/14.jpg', 'gt': None},
#  ...]

# %%
class CustomDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None,max_images =10):
        """
        Args:
            csv_file (string): Path to the csv file with annotations.
            root_dir (string): Directory with all the images.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.data_frame = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.max_images = max_images

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        folder_name = os.path.join(self.root_dir, self.data_frame.iloc[idx, -1])
        image_count = len(os.listdir(folder_name))
        print("folder {}".format(folder_name))
        
        images = [Image.open(os.path.join(folder_name, f"{i}.jpg")) for i in range(image_count)]
        print("images {}".format(len(images)))
        
        # Normalize and convert images to tensor
        if self.transform:
            images = [self.transform(image) for image in images]
        
        while len(images) < self.max_images:
            zero_tensor = torch.zeros([3, 224, 224])  # Assuming the images are 224x224 and 3-channel after transformation
            images.append(zero_tensor)
        images = torch.stack(images)  # Assuming all images in folder are related and stacking them into a single tensor
        
        labels = self.data_frame.iloc[idx, :-2]  # Excluding ID and Folder columns
        labels = torch.tensor(labels.values.astype('float32'))
        
        return images, labels

# %%
# Transformation (Normalization)
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # Resizing to 224x224 for example
    transforms.ToTensor(),  # Transform it to a tensor
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # Normalizing
])

# %%
dataset = CustomDataset(csv_file=csv_path, root_dir=root_path, transform=transform)

def collate_fn(batch):
    images, labels = zip(*batch)
    
    # Pad images
    images = pad_sequence(images, batch_first=True, padding_value=0)
    
    # Stack labels
    labels = torch.stack(labels)
    
    return images, labels

# DataLoader with custom collate_fn
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)

# Display a sample batch
for i_batch, (images, labels) in enumerate(dataloader):
    print(f"Batch {i_batch + 1}")
    print(f"Images shape: {images.shape}, Labels shape: {labels.shape}")
    break  # Display only one batch
# Out:
# folder F:\Train\Train\1578_L
# images 9
# folder F:\Train\Train\745_L
# images 23
# folder F:\Train\Train\512_R
# images 3
# folder F:\Train\Train\187_L
# images 14
# Batch 1
# Images shape: torch.Size([4, 23, 3, 224, 224]), Labels shape: torch.Size([4, 14])

# %% [markdown]
# ##  处理csv文件

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# 读取CSV文件
data_frame = pd.read_csv('F:/Train/Train/Train.csv')

# 初始化LabelEncoder
label_encoder = LabelEncoder()

# 创建一个新的DataFrame用于存储转换后的数据
transformed_data_frame = data_frame.copy()

# 对每一个标签列应用LabelEncoder
for column in data_frame.columns[:-2]:  # 排除 ID 和 Folder 列
    transformed_data_frame[column] = label_encoder.fit_transform(data_frame[column])

# 保存转换后的DataFrame
transformed_data_frame.to_csv('F:/Train/Transformed_Train.csv', index=False)
